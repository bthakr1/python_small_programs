# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import matplotlib.pyplot as plt

import os
import warnings

# %%
titanic = pd.read_csv('titatnic_train.csv')
titanic.drop(columns={'PassengerId','Name','Ticket','Cabin'}, inplace=True)
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
titanic.head()

titanic['Pclass'] = titanic['Pclass'].astype('object')
titanic['SibSp'] = titanic['SibSp'].astype('object')
titanic['Parch'] = titanic['Parch'].astype('object')
titanic['Survived'] = titanic['Survived'].astype('object')

titanic['Age'].fillna(value=titanic['Age'].mean(),inplace=True)

titanic['Age'] = titanic['Age'].astype('int32')

# %%
plt.figure(figsize=(12,8))
sns.countplot(titanic['Survived']);
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.distplot(titanic['Age'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.distplot(titanic['Fare'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(titanic['Embarked'])
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(titanic['Pclass'])
plt.show()

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, LabelEncoder, LabelBinarizer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import numpy as np

# %%
X = titanic.drop('Survived', axis=1)
y = titanic['Survived']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X,y,random_state=123,stratify=y, train_size=0.7)

# %%
X_train.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 623 entries, 199 to 768
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    623 non-null    object
#  1   Sex       623 non-null    object
#  2   Age       623 non-null    int32
#  3   SibSp     623 non-null    object
#  4   Parch     623 non-null    object
#  5   Fare      623 non-null    float64
#  6   Embarked  622 non-null    object
# dtypes: float64(1), int32(1), object(5)
# memory usage: 36.5+ KB

# %%
num_tranformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

cat_transfomrer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot',OneHotEncoder(handle_unknown='ignore', sparse='False'))
])

# %%
numeric_columns = list(X_train.select_dtypes(include=['float64','int32','int64']))
categorical_columns = list(X_train.select_dtypes(include=['object']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-1a87145e61d0> in <module>
# ----> 1 numeric_columns = list(X_train.select_dtypes(include=['float64','int32','int64']))
#       2 categorical_columns = list(X_train.select_dtypes(include=['object']))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'select_dtypes'

# %%
preprocessor = ColumnTransformer(transformers=[
    ('num',num_tranformer,numeric_columns),
    ('cat',cat_transfomrer,categorical_columns)
], remainder='passthrough')

# %%
pipe = Pipeline(steps=[('preprocessor', preprocessor)])

# %%
X_train = pipe.fit_transform(X_train)

# %%
X_valid = pipe.fit_transform(X_valid)

# %%
label_encoder = LabelEncoder()

y_train = label_encoder.fit_transform(y_train)

y_valid = label_encoder.fit_transform(y_valid)

# %%
estimator = KNeighborsClassifier(n_neighbors=3)

# %%
estimator.fit(X_train,np.ravel(y_train))
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_predict = estimator.predict(X_valid)

# %%
score = estimator.score(X_valid,y_valid)

# %%
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score

# %%
recall_score(y_valid,y_predict)
# Out:
# 0.6990291262135923

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_valid,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       165
#            1       0.67      0.70      0.69       103
#
#     accuracy                           0.75       268
#    macro avg       0.74      0.74      0.74       268
# weighted avg       0.76      0.75      0.75       268

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
knn = KNeighborsClassifier()

from pprint import pprint

# %%
knn.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
param_grid = {
    'algorithm' : ['auto','brute'],
    'n_neighbors' : [int(x) for x in np.linspace(start=3,stop=11,num=5)]
}

# %%
clf = RandomizedSearchCV(estimator=knn,param_distributions=param_grid,n_iter=10,n_jobs=-1,verbose=2,cv=5)

# %%
best_model = clf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    4.9s finished

# %%
best_model.best_estimator_.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 11,
#  'p': 2,
#  'weights': 'uniform'}

# %%
knn2 = KNeighborsClassifier(algorithm = 'brute', leaf_size = 30, metric = 'minkowski', metric_params = None, n_jobs = None, n_neighbors = 5, p = 2, weights='uniform')

# %%
knn2.fit(X_train,np.ravel(y_train))
# Out:
# KNeighborsClassifier(algorithm='brute')

# %%
y_pred_new = knn2.predict(X_valid)

# %%
print('Classification Report', classification_report(y_valid,y_pred_new))
# Out:
# Classification Report               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81       165
#            1       0.71      0.68      0.69       103
#
#     accuracy                           0.77       268
#    macro avg       0.76      0.75      0.75       268
# weighted avg       0.77      0.77      0.77       268
